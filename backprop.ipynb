# %%
from backprop_demo.backprop import experiment

# %%
# Default args
args = dict(
    seed=1,
    lr=1,
    init_std=0.1,
    bonus=False,
    n_hidden_nodes=2,
    n_iters=10000,
    plot_before=False,
    verbose=False,
    save=False
)

# %%
experiment(**args)
# Out:
# 100% accuracy
# [[-9.55  3.3 ]
#  [ 6.18 -7.81]
#  [ 6.18 -7.82]]
# [[  7.29]
#  [-14.94]
#  [-14.69]]

# %%
args2 = args.copy()
args2["bonus"] = True
experiment(**args2)
# Out:
# 71% accuracy
# [[-6.43  2.46]
#  [ 4.22 -6.19]
#  [ 4.22 -6.19]]
# [[ 1.53]
#  [-9.18]
#  [-9.1 ]]
